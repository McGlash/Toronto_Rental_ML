# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# Dependencies
from pymongo import MongoClient
import pandas as pd
import numpy as np
from datetime import datetime
import re
import pickle


from urls_list import * #where all urls and paths are saved

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Get the current rentals

# %%
client = MongoClient(db_connection_string)
records = list(client.ETLInsights["CurrentRental"].find({}, {'_id':0}))

# %%
DF = pd.DataFrame(records)

# %%
def feasibilityCheck(row):
    if (not row["FSA"]) or (not row["rental_type"]) or (not re.search('^M', row["FSA"])):
        return False
    if row["sqft"]:
        if (row["sqft"]>3000) or (row["sqft"]<200):
            return False
    return True

# %%
#DF['feasibility'] = DF.apply(lambda x: feasibilityCheck(x), axis=1)

# %%
def preprocess(DF):
    feasibility = DF.apply(lambda x: feasibilityCheck(x), axis=1)
    DF = DF[feasibility]
    #Replace all white spaces or nothing at all to NaN
    DF.replace(r'^\s*$', np.nan, regex=True, inplace=True)
    #Replace None with NaN
    DF = DF.fillna(value=np.nan)
    #Typecast
    DF['price'] = DF['price'].astype('int') #Not required
    #Missing value handling
    DF['furnished'] = DF['furnished'].fillna(value="NOT_MENTIONED")
    DF['furnished'] = DF['furnished'].replace(to_replace=True, value='YES')
    DF['furnished'] = DF['furnished'].replace(to_replace=False, value='NO')
    #New features 
    DF['post_published_date'] = DF['post_published_date'].map(lambda x: datetime.strptime(x, '%Y-%m-%d'))
    DF['posted_week_of_month'] = DF['post_published_date'].map(lambda x: x.day//7 +1)
    ##Convert image url to image or not? (New feature)
    DF['image'] = DF['image'].notna()
    #Basic transformation
    DF.reset_index(drop=True, inplace=True)
    #OHE
    num_columns = ['sqft', 'bedrooms', 'bathrooms', 'posted_week_of_month']
    cat_columns = ['image', 'FSA', 'rental_type', 'furnished', 'pet_friendly']
    enc = pickle.load(open('OHE.pickle', 'rb'))
    ##OHE Transform
    ohe_output = enc.transform(DF[cat_columns]).toarray()
    ohe_dict = {f'x{index}':col for index,col in enumerate(cat_columns)}
    ohe_labels = [ohe_dict[feature.split('_')[0]]+'_'+feature.split('_')[1] for feature in enc.get_feature_names()]
    DF = pd.concat([DF, pd.DataFrame(ohe_output, columns=ohe_labels)], axis=1)
    DF.drop(cat_columns, axis=1, inplace=True)
    selected_columns = ['sqft', 'bedrooms', 'bathrooms', 'image_False', 'FSA_M1B', 'FSA_M1M',
       'FSA_M1P', 'FSA_M1V', 'FSA_M1W', 'FSA_M2M', 'FSA_M3C', 'FSA_M3K',
       'FSA_M4E', 'FSA_M4V', 'FSA_M4W', 'FSA_M5G', 'FSA_M5J', 'FSA_M5R',
       'FSA_M5S', 'FSA_M5V', 'FSA_M6B', 'FSA_M6E', 'FSA_M6G', 'FSA_M6J',
       'FSA_M6K', 'FSA_M6M', 'FSA_M6P', 'rental_type_apartment',
       'rental_type_condo', 'rental_type_house', 'rental_type_loft',
       'rental_type_townhouse', 'furnished_NOT', 'furnished_YES',
       'pet_friendly_False']
    DF = DF[['id']+selected_columns]
    return DF, selected_columns

# %%
#New_DF, selected_columns = preprocess(DF)

# %%
def predict(DF, selected_columns):
    xgb_model = pickle.load(open('xgb_model.pickle', 'rb'))
    y_pred = xgb_model.predict(DF[selected_columns])
    DF['pred'] = y_pred
    prediction_mapping = DF[['id', 'pred']].set_index('id').T.to_dict()
    return prediction_mapping

# %%
#prediction_mapping = predict(New_DF,selected_columns)

# %%
#DF['pred'] = DF['id'].map(lambda x: prediction_mapping[x]['pred'] if x in prediction_mapping else 'Not Feasible to predict')

# %%
#MSE = 457.09

# %%
def predictPrice(DF):
    New_DF, selected_columns = preprocess(DF)
    prediction_mapping = predict(New_DF,selected_columns)
    DF['pred'] = DF['id'].map(lambda x: prediction_mapping[x]['pred'] if x in prediction_mapping else 'Not Feasible to predict')
    return DF

# %%
DF = predictPrice(DF)

# %%
DF
# Out:
#                 id                                              title price  \
# 0     c_7202750011                2 Bedroom, 2 Bathroom - Boutique II  2750
# 1     c_7202745971                1 Bed/room, 1 Bathroom - Boutique 2  1800
# 2     c_7202739547           1 Bedroom, 1 Bathroom - Boutique 2 Condo  1850
# 3     c_7202742727                1 Bed/room, 1 Bathroom - Boutique 2  1950
# 4     c_7202759816              1+1 Bedroom / 1 Bathroom - Boutique 2  2200
# ...            ...                                                ...   ...
# 2872  c_7227121433                           Condo apartment for rent  1525
# 2873  c_7227100416  Must see 1 bdrm, heat hot water included Avail...  2495
# 2874  c_7227109860  1-Year NEW Condo FOR RENT Near Faiview Mall, H...  2100
# 2875  c_7227105840  second floor apartment in house - ALL util inc...  1750
# 2876  c_7223058213  Beautiful Boutique Building Downtown Toronto -...  1700
#
#      sqft                                              image  \
# 0          https://images.craigslist.org/01616_hbR46WGFjY...
# 1          https://images.craigslist.org/00P0P_1L9TKA9cQH...
# 2          https://images.craigslist.org/01313_4YxX8zhMSe...
# 3          https://images.craigslist.org/00n0n_QNIkGEekZg...
# 4          https://images.craigslist.org/00000_3hsx9Gkt2W...
# ...   ...                                                ...
# 2872  400  https://images.craigslist.org/00808_7w0v9ix1Xp...
# 2873
# 2874  703  https://images.craigslist.org/00606_2qT1JfxwXg...
# 2875  500  https://images.craigslist.org/00505_1JhZoWtH1E...
# 2876  750
#
#                                                     url post_published_date  \
# 0     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 1     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 2     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 3     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 4     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# ...                                                 ...                 ...
# 2872  https://toronto.craigslist.org/tor/apa/d/toron...          2020-11-07
# 2873  https://toronto.craigslist.org/tor/apa/d/toron...          2020-11-07
# 2874  https://toronto.craigslist.org/tor/apa/d/north...          2020-11-07
# 2875  https://toronto.craigslist.org/tor/apa/d/toron...          2020-11-07
# 2876  https://toronto.craigslist.org/tor/apa/d/toron...          2020-10-30
#
#             lat       long postal_code  FSA rental_type bedrooms bathrooms  \
# 0     43.646067 -79.385474     M5J 1H8  M5J   apartment        2         2
# 1     43.646067 -79.385474     M5J 1H8  M5J       condo        1         1
# 2     43.646067 -79.385474     M5J 1H8  M5J       condo        1         1
# 3     43.646067 -79.385474     M5J 1H8  M5J   apartment        1         1
# 4     43.652102 -79.388075     M5T 3M3  M5T       condo        1         1
# ...         ...        ...         ...  ...         ...      ...       ...
# 2872  43.688605 -79.300990     M4C 1L4  M4C   apartment        0         1
# 2873  43.696600 -79.412000     M5P 2P8  M5P   apartment        1         1
# 2874  43.780100 -79.347900         M2J  M2J       condo        2         2
# 2875  43.648600 -79.482500     M6S 3X3  M6S       house        1         1
# 2876  43.669192 -79.375964     M4X 1W5  M4X       condo        1         1
#
#      furnished  pet_friendly  \
# 0        False         False
# 1        False         False
# 2        False         False
# 3        False         False
# 4        False         False
# ...        ...           ...
# 2872                   False
# 2873                   False
# 2874                   False
# 2875      True         False
# 2876                    True
#
#                                             description      source     pred
# 0     2BR / 2Ba available oct 15 apartment w/d in un...  craigslist  2915.22
# 1     1BR / 1Ba available oct 1 condo w/d in unit/ 1...  craigslist  1953.22
# 2     1BR / 1Ba available now condo w/d in unit/ 1br...  craigslist  1953.22
# 3     1BR / 1Ba available nov 1 apartment w/d in uni...  craigslist  1845.07
# 4     1BR / 1Ba available nov 1 condo w/d in unit/ 1...  craigslist   1926.6
# ...                                                 ...         ...      ...
# 2872  0BR / 1Ba 400ft2 available dec 1 apartment lau...  craigslist  1397.63
# 2873  1BR / 1Ba available dec 1 apartment laundry in...  craigslist  1611.49
# 2874  2BR / 2Ba 703ft2 available now apartment w/d i...  craigslist  2417.72
# 2875  1BR / 1Ba 500ft2 available dec 1 apartment w/d...  craigslist  1361.09
# 2876  1BR / 1Ba 750ft2 cats are OK - purrr apartment...  craigslist  2077.98
#
# [2877 rows x 19 columns]

# %%
len(records)
# Out:
# 12103

# %% [markdown]
# ## Update the DB with pred value

# %%
# for index,row in DF.iterrows():
#     #print(row['id'], row['pred'])
#     query = {'id': row['id']}
#     client.ETLInsights["HistoricRental"].update_one(query, {"$set": {"pred": row['pred']}})

# %%
client = MongoClient(db_connection_string)
records = list(client.ETLInsights["CurrentRental"].find({}, {'_id':0}))

# %%
DF = pd.DataFrame(records)

# %%
DF
# Out:
#                 id                                              title price  \
# 0     c_7202750011                2 Bedroom, 2 Bathroom - Boutique II  2750
# 1     c_7202745971                1 Bed/room, 1 Bathroom - Boutique 2  1800
# 2     c_7202739547           1 Bedroom, 1 Bathroom - Boutique 2 Condo  1850
# 3     c_7202742727                1 Bed/room, 1 Bathroom - Boutique 2  1950
# 4     c_7202759816              1+1 Bedroom / 1 Bathroom - Boutique 2  2200
# ...            ...                                                ...   ...
# 2872  c_7227121433                           Condo apartment for rent  1525
# 2873  c_7227100416  Must see 1 bdrm, heat hot water included Avail...  2495
# 2874  c_7227109860  1-Year NEW Condo FOR RENT Near Faiview Mall, H...  2100
# 2875  c_7227105840  second floor apartment in house - ALL util inc...  1750
# 2876  c_7223058213  Beautiful Boutique Building Downtown Toronto -...  1700
#
#      sqft                                              image  \
# 0          https://images.craigslist.org/01616_hbR46WGFjY...
# 1          https://images.craigslist.org/00P0P_1L9TKA9cQH...
# 2          https://images.craigslist.org/01313_4YxX8zhMSe...
# 3          https://images.craigslist.org/00n0n_QNIkGEekZg...
# 4          https://images.craigslist.org/00000_3hsx9Gkt2W...
# ...   ...                                                ...
# 2872  400  https://images.craigslist.org/00808_7w0v9ix1Xp...
# 2873
# 2874  703  https://images.craigslist.org/00606_2qT1JfxwXg...
# 2875  500  https://images.craigslist.org/00505_1JhZoWtH1E...
# 2876  750
#
#                                                     url post_published_date  \
# 0     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 1     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 2     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 3     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# 4     https://toronto.craigslist.org/tor/apa/d/toron...          2020-09-25
# ...                                                 ...                 ...
# 2872  https://toronto.craigslist.org/tor/apa/d/toron...          2020-11-07
# 2873  https://toronto.craigslist.org/tor/apa/d/toron...          2020-11-07
# 2874  https://toronto.craigslist.org/tor/apa/d/north...          2020-11-07
# 2875  https://toronto.craigslist.org/tor/apa/d/toron...          2020-11-07
# 2876  https://toronto.craigslist.org/tor/apa/d/toron...          2020-10-30
#
#             lat       long postal_code  FSA rental_type bedrooms bathrooms  \
# 0     43.646067 -79.385474     M5J 1H8  M5J   apartment        2         2
# 1     43.646067 -79.385474     M5J 1H8  M5J       condo        1         1
# 2     43.646067 -79.385474     M5J 1H8  M5J       condo        1         1
# 3     43.646067 -79.385474     M5J 1H8  M5J   apartment        1         1
# 4     43.652102 -79.388075     M5T 3M3  M5T       condo        1         1
# ...         ...        ...         ...  ...         ...      ...       ...
# 2872  43.688605 -79.300990     M4C 1L4  M4C   apartment        0         1
# 2873  43.696600 -79.412000     M5P 2P8  M5P   apartment        1         1
# 2874  43.780100 -79.347900         M2J  M2J       condo        2         2
# 2875  43.648600 -79.482500     M6S 3X3  M6S       house        1         1
# 2876  43.669192 -79.375964     M4X 1W5  M4X       condo        1         1
#
#      furnished  pet_friendly  \
# 0        False         False
# 1        False         False
# 2        False         False
# 3        False         False
# 4        False         False
# ...        ...           ...
# 2872                   False
# 2873                   False
# 2874                   False
# 2875      True         False
# 2876                    True
#
#                                             description      source     pred
# 0     2BR / 2Ba available oct 15 apartment w/d in un...  craigslist  2915.22
# 1     1BR / 1Ba available oct 1 condo w/d in unit/ 1...  craigslist  1953.22
# 2     1BR / 1Ba available now condo w/d in unit/ 1br...  craigslist  1953.22
# 3     1BR / 1Ba available nov 1 apartment w/d in uni...  craigslist  1845.07
# 4     1BR / 1Ba available nov 1 condo w/d in unit/ 1...  craigslist   1926.6
# ...                                                 ...         ...      ...
# 2872  0BR / 1Ba 400ft2 available dec 1 apartment lau...  craigslist  1397.63
# 2873  1BR / 1Ba available dec 1 apartment laundry in...  craigslist  1611.49
# 2874  2BR / 2Ba 703ft2 available now apartment w/d i...  craigslist  2417.72
# 2875  1BR / 1Ba 500ft2 available dec 1 apartment w/d...  craigslist  1361.09
# 2876  1BR / 1Ba 750ft2 cats are OK - purrr apartment...  craigslist  2077.98
#
# [2877 rows x 19 columns]
